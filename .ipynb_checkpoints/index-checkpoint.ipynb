# %%
# !pip install mapclassify
# Out:
# Collecting mapclassify
#   Downloading mapclassify-2.9.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: networkx>=3.2 in /usr/local/lib/python3.11/dist-packages (from mapclassify) (3.5)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.11/dist-packages (from mapclassify) (2.0.2)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.11/dist-packages (from mapclassify) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.4 in /usr/local/lib/python3.11/dist-packages (from mapclassify) (1.6.1)
# Requirement already satisfied: scipy>=1.12 in /usr/local/lib/python3.11/dist-packages (from mapclassify) (1.15.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->mapclassify) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->mapclassify) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->mapclassify) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4->mapclassify) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4->mapclassify) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.1->mapclassify) (1.17.0)
# Downloading mapclassify-2.9.0-py3-none-any.whl (286 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.7/286.7 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: mapclassify
# Successfully installed mapclassify-2.9.0

# %%
indiaMapsLink = 'https://github.com/FabioGM-02/Tarea-5/raw/refs/heads/main/Maps/indiaMaps_7755.gpkg'

import geopandas as gpd

gpd.list_layers(indiaMapsLink)
# Out:
#        name    geometry_type
# 0   country     MultiPolygon
# 1    cities            Point
# 2    rivers  MultiLineString
# 3  centroid            Point
# 4  airports            Point
# 5    states     MultiPolygon

# %%
airports=gpd.read_file(indiaMapsLink,layer='airports')
rivers=gpd.read_file(indiaMapsLink,layer='rivers')
cities=gpd.read_file(indiaMapsLink,layer='cities')

# %%
import pandas as pd

portsFileLink="https://github.com/CienciaDeDatosEspacial/GeoDataFrame_Analytics/raw/main/data/UpdatedPub150.csv"
infoseaports=pd.read_csv(portsFileLink)

# columns available (so many)
infoseaports.columns.to_list()
# Out:
# ['World Port Index Number',
#  'Region Name',
#  'Main Port Name',
#  'Alternate Port Name',
#  'UN/LOCODE',
#  'Country Code',
#  'World Water Body',
#  'IHO S-130 Sea Area',
#  'Sailing Direction or Publication',
#  'Publication Link',
#  'Standard Nautical Chart',
#  'IHO S-57 Electronic Navigational Chart',
#  'IHO S-101 Electronic Navigational Chart',
#  'Digital Nautical Chart',
#  'Tidal Range (m)',
#  'Entrance Width (m)',
#  'Channel Depth (m)',
#  'Anchorage Depth (m)',
#  'Cargo Pier Depth (m)',
#  'Oil Terminal Depth (m)',
#  'Liquified Natural Gas Terminal Depth (m)',
#  'Maximum Vessel Length (m)',
#  'Maximum Vessel Beam (m)',
#  'Maximum Vessel Draft (m)',
#  'Offshore Maximum Vessel Length (m)',
#  'Offshore Maximum Vessel Beam (m)',
#  'Offshore Maximum Vessel Draft (m)',
#  'Harbor Size',
#  'Harbor Type',
#  'Harbor Use',
#  'Shelter Afforded',
#  'Entrance Restriction - Tide',
#  'Entrance Restriction - Heavy Swell',
#  'Entrance Restriction - Ice',
#  'Entrance Restriction - Other',
#  'Overhead Limits',
#  'Underkeel Clearance Management System',
#  'Good Holding Ground',
#  'Turning Area',
#  'Port Security',
#  'Estimated Time of Arrival Message',
#  'Quarantine - Pratique',
#  'Quarantine - Sanitation',
#  'Quarantine - Other',
#  'Traffic Separation Scheme',
#  'Vessel Traffic Service',
#  'First Port of Entry',
#  'US Representative',
#  'Pilotage - Compulsory',
#  'Pilotage - Available',
#  'Pilotage - Local Assistance',
#  'Pilotage - Advisable',
#  'Tugs - Salvage',
#  'Tugs - Assistance',
#  'Communications - Telephone',
#  'Communications - Telefax',
#  'Communications - Radio',
#  'Communications - Radiotelephone',
#  'Communications - Airport',
#  'Communications - Rail',
#  'Search and Rescue',
#  'NAVAREA',
#  'Facilities - Wharves',
#  'Facilities - Anchorage',
#  'Facilities - Dangerous Cargo Anchorage',
#  'Facilities - Med Mooring',
#  'Facilities - Beach Mooring',
#  'Facilities - Ice Mooring',
#  'Facilities - Ro-Ro',
#  'Facilities - Solid Bulk',
#  'Facilities - Liquid Bulk',
#  'Facilities - Container',
#  'Facilities - Breakbulk',
#  'Facilities - Oil Terminal',
#  'Facilities - LNG Terminal',
#  'Facilities - Other',
#  'Medical Facilities',
#  'Garbage Disposal',
#  'Chemical Holding Tank Disposal',
#  'Degaussing',
#  'Dirty Ballast Disposal',
#  'Cranes - Fixed',
#  'Cranes - Mobile',
#  'Cranes - Floating',
#  'Cranes - Container',
#  'Lifts - 100+ Tons',
#  'Lifts - 50-100 Tons',
#  'Lifts - 25-49 Tons',
#  'Lifts - 0-24 Tons',
#  'Services - Longshoremen',
#  'Services - Electricity',
#  'Services - Steam',
#  'Services - Navigation Equipment',
#  'Services - Electrical Repair',
#  'Services - Ice Breaking',
#  'Services - Diving',
#  'Supplies - Provisions',
#  'Supplies - Potable Water',
#  'Supplies - Fuel Oil',
#  'Supplies - Diesel Oil',
#  'Supplies - Aviation Fuel',
#  'Supplies - Deck',
#  'Supplies - Engine',
#  'Repairs',
#  'Dry Dock',
#  'Railway',
#  'Latitude',
#  'Longitude']

# %%
# renamming
infoseaports.rename(columns={'Main Port Name':'portName'},inplace=True)
# keeping few columns
infoseaports=infoseaports.loc[:,['portName', 'Country Code','Latitude', 'Longitude']]

# we have now
infoseaports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3739 entries, 0 to 3738
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   portName      3739 non-null   object
#  1   Country Code  3739 non-null   object
#  2   Latitude      3739 non-null   float64
#  3   Longitude     3739 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 117.0+ KB

# %%
# spatial points
seaports=gpd.GeoDataFrame(data=infoseaports.copy(),
                           geometry=gpd.points_from_xy(infoseaports.Longitude,
                                                       infoseaports.Latitude),
                          crs=4326)# notice it is unprojected

# keeping India
seaports_ind=seaports[seaports['Country Code']=='India'].copy()

# reset indexes
seaports_ind.reset_index(drop=True, inplace=True)

# reprojecting
seaports_ind_7755=seaports_ind.to_crs(7755)

# %%
# subsetting
largeAirports=airports[airports['kind']=='large_airport']
largeAirports.reset_index(drop=True, inplace=True)

# plotting
base=largeAirports.plot(color='red',marker="^")
seaports_ind_7755.plot(ax=base,alpha=0.5,markersize=3)
# Out:
# <Axes: >

# %% [markdown]
# Exercise 1

# %%
distanceMatrixKM_sea_air= seaports_ind_7755.set_index('portName').geometry.apply\
                          (lambda g: largeAirports.set_index('name').geometry.distance(g)/1000).\
                          sort_index(axis=0).sort_index(axis=1)

# %%
# getting the geometry of the points
selected_seaport_geom = seaports_ind_7755[seaports_ind_7755['portName'] == distanceMatrixKM_sea_air.iloc[0].name].geometry
selected_airport_geom = largeAirports[largeAirports['name'] == distanceMatrixKM_sea_air.iloc[0].idxmin(axis=0)].geometry

# loading India's boundary for plotting
india_boundary = gpd.read_file(indiaMapsLink, layer='country')

# %%
base=india_boundary.explore(facecolor='none', edgecolor='none')
selected_airport_geom.explore(m=base,color='red',marker_kwds=dict(radius=10))
selected_seaport_geom.explore(m=base,color='blue',marker_kwds=dict(radius=5))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0be399c08ecdf2fe2fce94806e04d28 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0be399c08ecdf2fe2fce94806e04d28&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0be399c08ecdf2fe2fce94806e04d28 = L.map(
#                 &quot;map_d0be399c08ecdf2fe2fce94806e04d28&quot;,
#                 {
#                     center: [21.125725507736203, 82.76238250732422],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_d0be399c08ecdf2fe2fce94806e04d28);
#
#
#
#
#
#             var tile_layer_de8ec73c812347dd5f663562ea502ac6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_de8ec73c812347dd5f663562ea502ac6.addTo(map_d0be399c08ecdf2fe2fce94806e04d28);
#
#
#             map_d0be399c08ecdf2fe2fce94806e04d28.fitBounds(
#                 [[6.745831966400142, 68.14422607421875], [35.505619049072266, 97.38053894042969]],
#                 {}
#             );
#
#
#         function geo_json_fe0ebbf369ba8637ee83889bc267f886_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_fe0ebbf369ba8637ee83889bc267f886_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_fe0ebbf369ba8637ee83889bc267f886_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_fe0ebbf369ba8637ee83889bc267f886_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_fe0ebbf369ba8637ee83889bc267f886_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_fe0ebbf369ba8637ee83889bc267f886.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_fe0ebbf369ba8637ee83889bc267f886_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);

# %% [markdown]
# Exercise 2

# %%
rivers.head()
# Out:
#           NAME SYSTEM                                           geometry
# 0       Ganges   None  MULTILINESTRING ((4002830.005 4746881.883, 399...
# 1  Brahmaputra   None  MULTILINESTRING ((5449883.491 4633709.06, 5433...
# 2        Indus   None  MULTILINESTRING ((2827133.854 4025152.519, 282...

# %%
#keep one:

rivers[rivers.NAME.str.contains('Ganges')]
# Out:
#      NAME SYSTEM                                           geometry
# 0  Ganges   None  MULTILINESTRING ((4002830.005 4746881.883, 399...

# %%
# distance from each airport to the Ganges
rivers[rivers.NAME.str.contains('Ganges')].geometry[0].distance(largeAirports.set_index('name').geometry)/1000
# Out:
# name
# Navi Mumbai International Airport                    1110.302110
# Chhatrapati Shivaji International Airport            1116.358925
# Rajkot International Airport                          982.853397
# Netaji Subhash Chandra Bose International Airport     248.922105
# Indira Gandhi International Airport                   124.409006
# Kempegowda International Airport                     1402.228051
# Cochin International Airport                         1768.506275
# Manohar International Airport                        1343.861047
# Dabolim Airport                                      1379.829539
# Rajiv Gandhi International Airport                    962.045552
# Chennai International Airport                        1358.186403
# Thiruvananthapuram International Airport             1928.517657
# Name: geometry, dtype: float64

# %%
distanceMatrixKM_riv_air=rivers.set_index('NAME').geometry.apply\
(lambda g: largeAirports.set_index('name').geometry.distance(g)/1000).\
sort_index(axis=0).sort_index(axis=1)
distanceMatrixKM_riv_air
# Out:
# name         Chennai International Airport  \
# NAME
# Brahmaputra                    1679.260655
# Ganges                         1358.186403
# Indus                          1710.340311
#
# name         Chhatrapati Shivaji International Airport  \
# NAME
# Brahmaputra                                1849.876526
# Ganges                                     1116.358925
# Indus                                       693.402344
#
# name         Cochin International Airport  Dabolim Airport  \
# NAME
# Brahmaputra                   2177.638950      1970.157566
# Ganges                        1768.506275      1379.829539
# Indus                         1721.646058      1081.191036
#
# name         Indira Gandhi International Airport  \
# NAME
# Brahmaputra                          1296.337648
# Ganges                                124.409006
# Indus                                 538.950716
#
# name         Kempegowda International Airport  Manohar International Airport  \
# NAME
# Brahmaputra                       1825.838178                    1944.202519
# Ganges                            1402.228051                    1343.861047
# Indus                             1516.897046                    1048.901990
#
# name         Navi Mumbai International Airport  \
# NAME
# Brahmaputra                        1836.171775
# Ganges                             1110.302110
# Indus                               715.508871
#
# name         Netaji Subhash Chandra Bose International Airport  \
# NAME
# Brahmaputra                                         322.627974
# Ganges                                              248.922105
# Indus                                              1435.454894
#
# name         Rajiv Gandhi International Airport  Rajkot International Airport  \
# NAME
# Brahmaputra                         1461.625754                   1909.737333
# Ganges                               962.045552                    982.853397
# Indus                               1262.835463                    318.913617
#
# name         Thiruvananthapuram International Airport
# NAME
# Brahmaputra                               2295.457166
# Ganges                                    1928.517657
# Indus                                     1914.018893

# %%
distanceMatrixKM_riv_air.loc['Ganges'].sort_values()
# Out:
# name
# Indira Gandhi International Airport                   124.409006
# Netaji Subhash Chandra Bose International Airport     248.922105
# Rajiv Gandhi International Airport                    962.045552
# Rajkot International Airport                          982.853397
# Navi Mumbai International Airport                    1110.302110
# Chhatrapati Shivaji International Airport            1116.358925
# Manohar International Airport                        1343.861047
# Chennai International Airport                        1358.186403
# Dabolim Airport                                      1379.829539
# Kempegowda International Airport                     1402.228051
# Cochin International Airport                         1768.506275
# Thiruvananthapuram International Airport             1928.517657
# Name: Ganges, dtype: float64

# %%
base=largeAirports.explore(color='red',marker_kwds=dict(radius=10))
rivers[rivers.NAME.str.contains('Ganges')].explore(m=base)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa3514110b653460ff7e3d8ee5896758 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa3514110b653460ff7e3d8ee5896758&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa3514110b653460ff7e3d8ee5896758 = L.map(
#                 &quot;map_fa3514110b653460ff7e3d8ee5896758&quot;,
#                 {
#                     center: [18.51887500000001, 79.74304599999999],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_fa3514110b653460ff7e3d8ee5896758);
#
#
#
#
#
#             var tile_layer_041ecc8610b8b61a7106475b1a0cd2ad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_041ecc8610b8b61a7106475b1a0cd2ad.addTo(map_fa3514110b653460ff7e3d8ee5896758);
#
#
#             map_fa3514110b653460ff7e3d8ee5896758.fitBounds(
#                 [[8.482119999999966, 71.039391], [28.555630000000047, 88.446701]],
#                 {}
#             );
#
#
#         function geo_json_20af5deb89043f9e00853d5c7e197d11_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_20af5deb89043f9e00853d5c7e197d11_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_20af5deb89043f9e00853d5c7e197d11_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 10,
# };
#
#             let style = geo_json_20af5deb89043f9e00853d5c7e197d11_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_20af5deb89043f9e00853d5c7e197d11_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_20af5deb89043f9e00853d5c7e197d11.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_20af5deb89043f9e00853d5c7e197d11_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_20af5deb89043f9e00853d5c7e197d11 = L.geoJson(null, {
#                 onEachFeature: geo_json_20af5deb89043f9e00853d5c7e197d11_onEachFeature,
#
#                 style: geo_json_20af5deb89043f9e00853d5c7e197d11_styler,
#                 pointToLayer: geo_json_20af5deb89043f9e00853d5c7e197d11_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_20af5deb89043f9e00853d5c7e197d11_add (

# %%
rivers[~rivers.SYSTEM.isna()]
# Out:
# Empty GeoDataFrame
# Columns: [NAME, SYSTEM, geometry]
# Index: []

# %%
rivers.drop(columns='SYSTEM',inplace=True)

# %%
rivers
# Out:
#           NAME                                           geometry
# 0       Ganges  MULTILINESTRING ((4002830.005 4746881.883, 399...
# 1  Brahmaputra  MULTILINESTRING ((5449883.491 4633709.06, 5433...
# 2        Indus  MULTILINESTRING ((2827133.854 4025152.519, 282...

# %%
distanceMatrixKM_sys_air=rivers.set_index('NAME').geometry.apply\
(lambda g: largeAirports.set_index('name').geometry.distance(g)/1000).\
sort_index(axis=0).sort_index(axis=1)

distanceMatrixKM_sys_air
# Out:
# name         Chennai International Airport  \
# NAME
# Brahmaputra                    1679.260655
# Ganges                         1358.186403
# Indus                          1710.340311
#
# name         Chhatrapati Shivaji International Airport  \
# NAME
# Brahmaputra                                1849.876526
# Ganges                                     1116.358925
# Indus                                       693.402344
#
# name         Cochin International Airport  Dabolim Airport  \
# NAME
# Brahmaputra                   2177.638950      1970.157566
# Ganges                        1768.506275      1379.829539
# Indus                         1721.646058      1081.191036
#
# name         Indira Gandhi International Airport  \
# NAME
# Brahmaputra                          1296.337648
# Ganges                                124.409006
# Indus                                 538.950716
#
# name         Kempegowda International Airport  Manohar International Airport  \
# NAME
# Brahmaputra                       1825.838178                    1944.202519
# Ganges                            1402.228051                    1343.861047
# Indus                             1516.897046                    1048.901990
#
# name         Navi Mumbai International Airport  \
# NAME
# Brahmaputra                        1836.171775
# Ganges                             1110.302110
# Indus                               715.508871
#
# name         Netaji Subhash Chandra Bose International Airport  \
# NAME
# Brahmaputra                                         322.627974
# Ganges                                              248.922105
# Indus                                              1435.454894
#
# name         Rajiv Gandhi International Airport  Rajkot International Airport  \
# NAME
# Brahmaputra                         1461.625754                   1909.737333
# Ganges                               962.045552                    982.853397
# Indus                               1262.835463                    318.913617
#
# name         Thiruvananthapuram International Airport
# NAME
# Brahmaputra                               2295.457166
# Ganges                                    1928.517657
# Indus                                     1914.018893

# %%
min_river_geom = largeAirports[largeAirports['name'] == distanceMatrixKM_sys_air.iloc[1].idxmin(axis=0)].geometry
max_river_geom = largeAirports[largeAirports['name'] == distanceMatrixKM_sys_air.iloc[1].idxmax(axis=0)].geometry

# %%
base=rivers.explore()
# the closest
min_river_geom.explore(m=base,color='red',marker_kwds=dict(radius=10))
# the farthest
max_river_geom.explore(m=base,color='blue',marker_kwds=dict(radius=5))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e620b8dbe5fb904753f9c198f86f2eb7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e620b8dbe5fb904753f9c198f86f2eb7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e620b8dbe5fb904753f9c198f86f2eb7 = L.map(
#                 &quot;map_e620b8dbe5fb904753f9c198f86f2eb7&quot;,
#                 {
#                     center: [29.26806168048585, 81.96317814186602],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_e620b8dbe5fb904753f9c198f86f2eb7);
#
#
#
#
#
#             var tile_layer_f1baa102d481d2605c9cbe9f748e9565 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f1baa102d481d2605c9cbe9f748e9565.addTo(map_e620b8dbe5fb904753f9c198f86f2eb7);
#
#
#             map_e620b8dbe5fb904753f9c198f86f2eb7.fitBounds(
#                 [[23.781042098999016, 68.23929115922033], [34.755081261972684, 95.68706512451172]],
#                 {}
#             );
#
#
#         function geo_json_d86c172dc6f343290b8177e19c0b3d38_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_d86c172dc6f343290b8177e19c0b3d38_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_d86c172dc6f343290b8177e19c0b3d38_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_d86c172dc6f343290b8177e19c0b3d38_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_d86c172dc6f343290b8177e19c0b3d38_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_d86c172dc6f343290b8177e19c0b3d38.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_d86c172dc6f343290b8177e19c0b3d38_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);

# %% [markdown]
# Exercise 3

# %%
rivers['SYSTEM'] = 'Himalayas'
rivers
# Out:
#           NAME                                           geometry     SYSTEM
# 0       Ganges  MULTILINESTRING ((4002830.005 4746881.883, 399...  Himalayas
# 1  Brahmaputra  MULTILINESTRING ((5449883.491 4633709.06, 5433...  Himalayas
# 2        Indus  MULTILINESTRING ((2827133.854 4025152.519, 282...  Himalayas

# %%
systems=rivers.dissolve(by='SYSTEM')
systems
# Out:
#                                                     geometry    NAME
# SYSTEM
# Himalayas  MULTILINESTRING ((4002830.005 4746881.883, 399...  Ganges

# %%
# format the GDF:

systems.reset_index(drop=False,inplace=True)
systems.drop(columns='NAME',inplace=True)

# we have
systems
# Out:
#       SYSTEM                                           geometry
# 0  Himalayas  MULTILINESTRING ((4002830.005 4746881.883, 399...

# %%
# polygon for each system
systems.convex_hull
# Out:
# 0    POLYGON ((2827133.854 4025152.519, 2827023.807...
# dtype: geometry

# %%
# see them
systems.convex_hull.plot()
# Out:
# <Axes: >

# %%
systems_hulls=systems.convex_hull.to_frame()
systems_hulls['system']=['Himalayas']
systems_hulls.rename(columns={0:'geometry'},inplace=True)
systems_hulls=systems_hulls.set_geometry('geometry')
systems_hulls.crs="EPSG:7755"
systems_hulls
# Out:
#                                             geometry     system
# 0  POLYGON ((2827133.854 4025152.519, 2827023.807...  Himalayas

# %%
distanceMatrixKM_sysHull_air=systems_hulls.set_index('system').geometry.apply\
(lambda g: largeAirports.set_index('name').geometry.distance(g)/1000).\
sort_index(axis=0).sort_index(axis=1)

distanceMatrixKM_sysHull_air
# Out:
# name       Chennai International Airport  \
# system
# Himalayas                    1285.620505
#
# name       Chhatrapati Shivaji International Airport  \
# system
# Himalayas                                 561.475367
#
# name       Cochin International Airport  Dabolim Airport  \
# system
# Himalayas                   1574.321836       974.589045
#
# name       Indira Gandhi International Airport  \
# system
# Himalayas                                  0.0
#
# name       Kempegowda International Airport  Manohar International Airport  \
# system
# Himalayas                       1247.307032                     935.201668
#
# name       Navi Mumbai International Airport  \
# system
# Himalayas                         574.804244
#
# name       Netaji Subhash Chandra Bose International Airport  \
# system
# Himalayas                                         248.922105
#
# name       Rajiv Gandhi International Airport  Rajkot International Airport  \
# system
# Himalayas                          810.396252                    185.707777
#
# name       Thiruvananthapuram International Airport
# system
# Himalayas                                 1764.9268

# %%
mins=distanceMatrixKM_sysHull_air.idxmin(axis="columns")
mins
# Out:
# system
# Himalayas    Indira Gandhi International Airport
# dtype: object

# %%
# plotting
base=systems_hulls.explore()
largeAirports[largeAirports.name.isin(mins)].explore(m=base,color='red',marker_kwds=dict(radius=10))
largeAirports[~largeAirports.name.isin(mins)].explore(m=base,color='blue',marker_kwds=dict(radius=5))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8aff1045c43807e3b09b720cb72de499 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8aff1045c43807e3b09b720cb72de499&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8aff1045c43807e3b09b720cb72de499 = L.map(
#                 &quot;map_8aff1045c43807e3b09b720cb72de499&quot;,
#                 {
#                     center: [29.26806168048585, 81.96317814186602],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_8aff1045c43807e3b09b720cb72de499);
#
#
#
#
#
#             var tile_layer_e694f4360409bc19cad63e091fb6e5ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e694f4360409bc19cad63e091fb6e5ca.addTo(map_8aff1045c43807e3b09b720cb72de499);
#
#
#             map_8aff1045c43807e3b09b720cb72de499.fitBounds(
#                 [[23.781042098999016, 68.23929115922033], [34.755081261972684, 95.68706512451172]],
#                 {}
#             );
#
#
#         function geo_json_f3b7f8bfe30d56b8fd870a6359c678cf_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_f3b7f8bfe30d56b8fd870a6359c678cf_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_f3b7f8bfe30d56b8fd870a6359c678cf_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_f3b7f8bfe30d56b8fd870a6359c678cf_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_f3b7f8bfe30d56b8fd870a6359c678cf_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_f3b7f8bfe30d56b8fd870a6359c678cf.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f3b7f8bfe30d56b8fd870a6359c678cf_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);

# %% [markdown]
# Exercise 4

# %%
# remember:
distanceMatrixKM_riv_air
# Out:
# name         Chennai International Airport  \
# NAME
# Brahmaputra                    1679.260655
# Ganges                         1358.186403
# Indus                          1710.340311
#
# name         Chhatrapati Shivaji International Airport  \
# NAME
# Brahmaputra                                1849.876526
# Ganges                                     1116.358925
# Indus                                       693.402344
#
# name         Cochin International Airport  Dabolim Airport  \
# NAME
# Brahmaputra                   2177.638950      1970.157566
# Ganges                        1768.506275      1379.829539
# Indus                         1721.646058      1081.191036
#
# name         Indira Gandhi International Airport  \
# NAME
# Brahmaputra                          1296.337648
# Ganges                                124.409006
# Indus                                 538.950716
#
# name         Kempegowda International Airport  Manohar International Airport  \
# NAME
# Brahmaputra                       1825.838178                    1944.202519
# Ganges                            1402.228051                    1343.861047
# Indus                             1516.897046                    1048.901990
#
# name         Navi Mumbai International Airport  \
# NAME
# Brahmaputra                        1836.171775
# Ganges                             1110.302110
# Indus                               715.508871
#
# name         Netaji Subhash Chandra Bose International Airport  \
# NAME
# Brahmaputra                                         322.627974
# Ganges                                              248.922105
# Indus                                              1435.454894
#
# name         Rajiv Gandhi International Airport  Rajkot International Airport  \
# NAME
# Brahmaputra                         1461.625754                   1909.737333
# Ganges                               962.045552                    982.853397
# Indus                               1262.835463                    318.913617
#
# name         Thiruvananthapuram International Airport
# NAME
# Brahmaputra                               2295.457166
# Ganges                                    1928.517657
# Indus                                     1914.018893

# %%
# getting a value (it can be any value)
distanceMatrixKM_riv_air.loc['Ganges'].min() # I chose min
# Out:
# 124.40900596441938

# %%
minMts=distanceMatrixKM_riv_air.loc['Ganges'].min()*1000 # km

#the buffer is a polygon:
rivers[rivers.NAME=='Ganges'].buffer(distance = minMts)
# Out:
# 0    POLYGON ((3734674.566 4693601.492, 3736334.4 4...
# dtype: geometry

# %%
# see buffer:
bufferAroundGanges=rivers[rivers.NAME=='Ganges'].buffer(distance = minMts)
bufferAsBase=bufferAroundGanges.explore(color='red')
rivers[rivers.NAME=='Ganges'].explore(m=bufferAsBase,color='blue',style_kwds={'weight':0.5})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29d6ebf18751f7609bbdc91747dc620d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29d6ebf18751f7609bbdc91747dc620d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29d6ebf18751f7609bbdc91747dc620d = L.map(
#                 &quot;map_29d6ebf18751f7609bbdc91747dc620d&quot;,
#                 {
#                     center: [27.89001173399341, 83.1656735561641],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_29d6ebf18751f7609bbdc91747dc620d);
#
#
#
#
#
#             var tile_layer_061d1472dffe3e7d07a3c558d5e5c587 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_061d1472dffe3e7d07a3c558d5e5c587.addTo(map_29d6ebf18751f7609bbdc91747dc620d);
#
#
#             map_29d6ebf18751f7609bbdc91747dc620d.fitBounds(
#                 [[23.788322314235327, 76.89535977135223], [31.991701153751496, 89.43598734097596]],
#                 {}
#             );
#
#
#         function geo_json_f7ff1ce7fd3cbf815e89f98fcd9ce8be_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_f7ff1ce7fd3cbf815e89f98fcd9ce8be_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_f7ff1ce7fd3cbf815e89f98fcd9ce8be_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_f7ff1ce7fd3cbf815e89f98fcd9ce8be_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_f7ff1ce7fd3cbf815e89f98fcd9ce8be_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_f7ff1ce7fd3cbf815e89f98fcd9ce8be.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f7ff1ce7fd3cbf815e89f98fcd9ce8be_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_f7ff1ce7fd3cbf815e89f98fcd9ce8be = L.geoJson(null, {
#                 onEachFeature: geo_json_f7ff1ce7fd3cbf815e89f98fcd9ce8be_onEachFeature,
#
#                 style: geo_json_f7ff1ce7fd3cbf815e89f98fcd9ce8be_styler,
#                 pointToLayer: geo_json_f7ff1ce7fd3cbf815e89f98fcd9ce8be_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_f7ff1ce7fd3cbf815e89f98

# %%
small_airports=airports[airports['kind']=='small_airport']

# plotting
rivers[rivers.NAME=='Ganges'].explore(m=bufferAsBase,color='blue',style_kwds={'weight':0.5})
small_airports.explore(m=bufferAsBase,color='black')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc7a210f5a084a2e4af2fed85e8fb333 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc7a210f5a084a2e4af2fed85e8fb333&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc7a210f5a084a2e4af2fed85e8fb333 = L.map(
#                 &quot;map_bc7a210f5a084a2e4af2fed85e8fb333&quot;,
#                 {
#                     center: [27.89001173399341, 83.1656735561641],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_bc7a210f5a084a2e4af2fed85e8fb333);
#
#
#
#
#
#             var tile_layer_0f19e4cf2b452568e4de6759dd99cf85 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0f19e4cf2b452568e4de6759dd99cf85.addTo(map_bc7a210f5a084a2e4af2fed85e8fb333);
#
#
#             map_bc7a210f5a084a2e4af2fed85e8fb333.fitBounds(
#                 [[23.788322314235327, 76.89535977135223], [31.991701153751496, 89.43598734097596]],
#                 {}
#             );
#
#
#         function geo_json_6d72938a11c67d524a95cb13ed8fe4e8_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_6d72938a11c67d524a95cb13ed8fe4e8_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_6d72938a11c67d524a95cb13ed8fe4e8_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &qu

# %%
riversWithinBuffer=small_airports.clip(mask=bufferAroundGanges)
# Out:
#                                           name           kind  latitude_deg  \
# 396                            Muirpur Airport  small_airport     24.125200
# 398                              Sidhi Airport  small_airport     24.402300
# 477                         Chitrakoot Airport  small_airport     25.167694
# 67                              Ulao Aerodrome  small_airport     25.427880
# 341                            Andhau Airfield  small_airport     25.615500
# 342                    Bihta Air Force Station  small_airport     25.591240
# 339                             Benti Airstrip  small_airport     25.672920
# 460                           Azamgarh Airport  small_airport     26.153333
# 95                           Surichua Air Base  small_airport     24.188240
# 98                          Sido Kanhu Airport  small_airport     24.231185
# 481                            Deoghar Airport  small_airport     24.446842
# 501                              Malda Airport  small_airport     25.010180
# 76                           Bhagalpur Airport  small_airport     25.249535
# 466                          Balurghat Airport  small_airport     25.261700
# 510                             Purnea Airport  small_airport     25.759600
# 577                         Fursatganj Airport  small_airport     26.248501
# 69                           Sultanpur Airport  small_airport     26.247500
# 66                           Madhubani Airport  small_airport     26.329167
# 535          Akbarpur Mahamaya Rajkiya Airport  small_airport     26.447599
# 544          Bakshi Ka Talab Air Force Station  small_airport     26.988300
# 89                             Saharsa Airport  small_airport     25.892205
# 565                 Kanpur Civil Airport (Old)  small_airport     26.440857
# 531                         IIT Kanpur Airport  small_airport     26.520399
# 338                        Marhamtabad Airport  small_airport     26.581820
# 520                             Saifai Airport  small_airport     26.920200
# 337                       Mohammadabad Airport  small_airport     27.316258
# 537                            Aligarh Airport  small_airport     27.861437
# 388                Noida International Airport  small_airport     28.175556
# 555  Hindon Airport / Hindon Air Force Station  small_airport     28.707701
# 409              Dr. Bhimrao Ambedkar Airstrip  small_airport     28.904933
# 522                             Karnal Airport  small_airport     29.714663
# 580                  Sarsawa Air Force Station  small_airport     29.994303
# 552                        Pithoragarh Airport  small_airport     29.593599
# 86                            Gauchar Airstrip  small_airport     30.284585
# 533               Maa Ganga Airport Uttarkashi  small_airport     30.582583
#
#      longitude_deg  elevation_ft       municipality  \
# 396      83.040604        1122.0               None
# 398      81.814796        1093.0               None
# 477      80.935800        1050.0         Chitrakoot
# 67       86.088190           NaN          Begusarai
# 341      83.560640           NaN            Biraich
# 342      84.883120           NaN              Patna
# 339      81.495920           NaN              Benti
# 460      83.118333         250.0           Azamgarh
# 95       87.701722         280.0          Rampurhat
# 98       87.269989         470.0              Dumka
# 481      86.704955         361.0            Deoghar
# 501      88.126917          79.0              Malda
# 76       87.011976           NaN          Bhagalpur
# 466      88.795601          78.0          Balurghat
# 510      87.410004         129.0               None
# 577      81.380501         360.0            Tarauna
# 69       82.042500           NaN          Sultanpur
# 66       86.060000           NaN          Madhubani
# 535      82.568199         288.0           Akbarpur
# 544      80.893097         385.0            Lucknow
# 89       86.583016           NaN            Saharsa
# 565      80.365029         411.0             Kanpur
# 531      80.232904         400.0             Kanpur
# 338      79.967970           NaN        Marhamtabad
# 520      79.062770           NaN      Barauli Khurd
# 337      79.451555           NaN       Mohammadabad
# 537      78.145404         619.0            Aligarh
# 388      77.606110           NaN               None
# 555      77.358902         700.0          Ghaziabad
# 409      77.677524         732.0             Meerut
# 522      77.037438         829.0             Niawal
# 580      77.424560         891.0  Sherpur Naqeebpur
# 552      80.239197        4910.0        Pithoragarh
# 86       79.161665           NaN            Gauchar
# 533      78.323164        2983.0       Chinyalisour
#
#                             geometry
# 396  POINT (4303047.269 4016867.255)
# 398  POINT (4180496.385 4044854.623)
# 477  POINT (4092522.669 4127140.007)
# 67   POINT (4600536.118 4168078.584)
# 341  POINT (4350776.569 4179921.605)
# 342  POINT (4481106.979 4181190.652)
# 339  POINT (4147317.278 4182510.973)
# 460  POINT (4305916.623 4237331.075)
# 95   POINT (4766909.354 4041409.553)
# 98   POINT (4723717.698 4043783.248)
# 481  POINT (4666399.368 4064389.376)
# 501  POINT (4804056.258 4132916.525)
# 76   POINT (4692551.609 4152961.109)
# 466  POINT (4868426.729 4164161.301)
# 510   POINT (4728914.74 4210321.062)
# 577  POINT (4135338.277 4244954.831)
# 69   POINT (4200235.531 4245634.365)
# 66   POINT (4593545.131 4265828.444)
# 535  POINT (4251370.513 4268230.436)
# 544  POINT (4087046.141 4325025.009)
# 89   POINT (4646954.578 4220677.591)
# 565  POINT (4035732.193 4265252.587)
# 531  POINT (4022784.374 4273874.613)
# 338  POINT (3996868.108 4280535.552)
# 520  POINT (3908603.194 4317644.424)
# 337  POINT (3946684.227 4360539.562)
# 537   POINT (3820495.88 4420971.482)
# 388  POINT (3768884.072 4455971.292)
# 555  POINT (3746107.493 4514391.273)
# 409  POINT (3777088.674 4535359.402)
# 522  POINT (3717519.657 4624880.328)
# 580  POINT (3754985.835 4654705.807)
# 552  POINT (4022831.558 4608706.377)
# 86    POINT (3920429.97 4684440.297)
# 533   POINT (3841234.99 4717749.402)

# %%
# plotting the airports within buffer
bufferAsBase=bufferAroundGanges.explore(color='red')
rivers[rivers.NAME=='Ganges'].explore(m=bufferAsBase,color='blue',style_kwds={'weight':0.5})
riversWithinBuffer.explore(m=bufferAsBase,color='black')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3827099923c615101e67307a95e387c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3827099923c615101e67307a95e387c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3827099923c615101e67307a95e387c8 = L.map(
#                 &quot;map_3827099923c615101e67307a95e387c8&quot;,
#                 {
#                     center: [27.89001173399341, 83.1656735561641],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_3827099923c615101e67307a95e387c8);
#
#
#
#
#
#             var tile_layer_6948ea65dd05d7d6b089c6b606209d89 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6948ea65dd05d7d6b089c6b606209d89.addTo(map_3827099923c615101e67307a95e387c8);
#
#
#             map_3827099923c615101e67307a95e387c8.fitBounds(
#                 [[23.788322314235327, 76.89535977135223], [31.991701153751496, 89.43598734097596]],
#                 {}
#             );
#
#
#         function geo_json_637d4cb86e89985ae5e3d607fa1e664e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_637d4cb86e89985ae5e3d607fa1e664e_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_637d4cb86e89985ae5e3d607fa1e664e_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_637d4cb86e89985ae5e3d607fa1e664e_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_637d4cb86e89985ae5e3d607fa1e664e_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_637d4cb86e89985ae5e3d607fa1e664e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_637d4cb86e89985ae5e3d607fa1e664e_highlighter(e.target.feature)

# %%
# minimum of all the minimum by row
distanceMatrixKM_riv_air.min(axis=1).min()
# Out:
# 124.40900596441938

# %%
# using the previous value
minMinMts_5=1*distanceMatrixKM_riv_air.min(axis=1).min()*1000

allMinBuffer=rivers.buffer(distance = minMinMts_5).explore(color='red')
rivers.explore(m=allMinBuffer,color='blue',style_kwds={'weight':0.5})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea890542d231cc4bc2c60775ed052cbd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea890542d231cc4bc2c60775ed052cbd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea890542d231cc4bc2c60775ed052cbd = L.map(
#                 &quot;map_ea890542d231cc4bc2c60775ed052cbd&quot;,
#                 {
#                     center: [29.255284836519408, 81.982899689321],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_ea890542d231cc4bc2c60775ed052cbd);
#
#
#
#
#
#             var tile_layer_0fdfc00409a78cfc59bf52e428503956 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0fdfc00409a78cfc59bf52e428503956.addTo(map_ea890542d231cc4bc2c60775ed052cbd);
#
#
#             map_ea890542d231cc4bc2c60775ed052cbd.fitBounds(
#                 [[22.635523043016295, 66.9933564448877], [35.87504663002252, 96.97244293375431]],
#                 {}
#             );
#
#
#         function geo_json_08aa41b74b5401bd68fb32a6256f80c1_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_08aa41b74b5401bd68fb32a6256f80c1_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_08aa41b74b5401bd68fb32a6256f80c1_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_08aa41b74b5401bd68fb32a6256f80c1_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_08aa41b74b5401bd68fb32a6256f80c1_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_08aa41b74b5401bd68fb32a6256f80c1.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_08aa41b74b5401bd68fb32a6256f80c1_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_08aa41b74b5401bd68fb32a6256f80c1 = L.geoJson(null, {
#                 onEachFeature: geo_json_08aa41b74b5401bd68fb32a6256f80c1_onEachFeature,
#
#                 style: geo_json_08aa41b74b5401bd68fb32a6256f80c1_styler,
#                 pointToLayer: geo_json_08aa41b74b5401bd68fb32a6256f80c1_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_08aa41b74b5401bd68fb32a62

# %%
# you see all the buffer polygons:
riversAll_buf=rivers.buffer(distance=minMinMts_5)
riversAll_buf
# Out:
# 0    POLYGON ((3734674.566 4693601.492, 3736334.4 4...
# 1    POLYGON ((5102081.831 4164041.712, 5099367.849...
# 2    MULTIPOLYGON (((3869222.791 4888710.348, 38657...
# dtype: geometry

# %%
allRiversWithinBuffs=small_airports.clip(riversAll_buf)
# Out:
#                                           name           kind  latitude_deg  \
# 396                            Muirpur Airport  small_airport     24.125200
# 398                              Sidhi Airport  small_airport     24.402300
# 477                         Chitrakoot Airport  small_airport     25.167694
# 67                              Ulao Aerodrome  small_airport     25.427880
# 341                            Andhau Airfield  small_airport     25.615500
# 342                    Bihta Air Force Station  small_airport     25.591240
# 339                             Benti Airstrip  small_airport     25.672920
# 460                           Azamgarh Airport  small_airport     26.153333
# 95                           Surichua Air Base  small_airport     24.188240
# 98                          Sido Kanhu Airport  small_airport     24.231185
# 481                            Deoghar Airport  small_airport     24.446842
# 501                              Malda Airport  small_airport     25.010180
# 76                           Bhagalpur Airport  small_airport     25.249535
# 466                          Balurghat Airport  small_airport     25.261700
# 510                             Purnea Airport  small_airport     25.759600
# 577                         Fursatganj Airport  small_airport     26.248501
# 69                           Sultanpur Airport  small_airport     26.247500
# 66                           Madhubani Airport  small_airport     26.329167
# 535          Akbarpur Mahamaya Rajkiya Airport  small_airport     26.447599
# 544          Bakshi Ka Talab Air Force Station  small_airport     26.988300
# 15                              Baljek Airport  small_airport     25.661488
# 89                             Saharsa Airport  small_airport     25.892205
# 514                              Rupsi Airport  small_airport     26.141867
# 476                        Cooch Behar Airport  small_airport     26.330500
# 473                   Chabua Air Force Station  small_airport     27.462200
# 356                            Dinjan Airfield  small_airport     27.536060
# 450            Sookerating (Doomdooma) Airport  small_airport     27.552900
# 483                           Daporijo Airport  small_airport     27.985500
# 515                               Tezu Airport  small_airport     27.941200
# 506                           Pasighat Airport  small_airport     28.064786
# 456            Mechuka Advanced Landing Ground  small_airport     28.602458
# 303             Tuting Advanced Landing Ground  small_airport     28.988760
# 402                   Naliya Air Force Station  small_airport     23.222300
# 565                 Kanpur Civil Airport (Old)  small_airport     26.440857
# 531                         IIT Kanpur Airport  small_airport     26.520399
# 338                        Marhamtabad Airport  small_airport     26.581820
# 520                             Saifai Airport  small_airport     26.920200
# 337                       Mohammadabad Airport  small_airport     27.316258
# 537                            Aligarh Airport  small_airport     27.861437
# 388                Noida International Airport  small_airport     28.175556
# 555  Hindon Airport / Hindon Air Force Station  small_airport     28.707701
# 409              Dr. Bhimrao Ambedkar Airstrip  small_airport     28.904933
# 522                             Karnal Airport  small_airport     29.714663
# 580                  Sarsawa Air Force Station  small_airport     29.994303
# 552                        Pithoragarh Airport  small_airport     29.593599
# 86                            Gauchar Airstrip  small_airport     30.284585
# 533               Maa Ganga Airport Uttarkashi  small_airport     30.582583
# 526             Fukche Advanced Landing Ground  small_airport     32.937401
# 298                             Nyoma Airstrip  small_airport     33.169130
# 275                           Chushul Airstrip  small_airport     33.554930
# 525                             Kargil Airport  small_airport     34.524300
# 524                             Thoise Airport  small_airport     34.652599
#
#      longitude_deg  elevation_ft       municipality  \
# 396      83.040604        1122.0               None
# 398      81.814796        1093.0               None
# 477      80.935800        1050.0         Chitrakoot
# 67       86.088190           NaN          Begusarai
# 341      83.560640           NaN            Biraich
# 342      84.883120           NaN              Patna
# 339      81.495920           NaN              Benti
# 460      83.118333         250.0           Azamgarh
# 95       87.701722         280.0          Rampurhat
# 98       87.269989         470.0              Dumka
# 481      86.704955         361.0            Deoghar
# 501      88.126917          79.0              Malda
# 76       87.011976           NaN          Bhagalpur
# 466      88.795601          78.0          Balurghat
# 510      87.410004         129.0               None
# 577      81.380501         360.0            Tarauna
# 69       82.042500           NaN          Sultanpur
# 66       86.060000           NaN          Madhubani
# 535      82.568199         288.0           Akbarpur
# 544      80.893097         385.0            Lucknow
# 15       90.345039           NaN               None
# 89       86.583016           NaN            Saharsa
# 514      89.907892         131.0              Rupsi
# 476      89.467201         138.0        Cooch Behar
# 473      95.117699         367.0             Chabua
# 356      95.268200         390.0      Baghbari Gaon
# 450      95.570602         400.0     Sokriting T.E.
# 483      94.222801         750.0           Daporijo
# 515      96.134399         800.0               Tezu
# 506      95.336952         477.0           Pasighat
# 456      94.126139        7900.0            Kargong
# 303      94.898630        1562.0             Tuting
# 402      68.891296         135.0             Naliya
# 565      80.365029         411.0             Kanpur
# 531      80.232904         400.0             Kanpur
# 338      79.967970           NaN        Marhamtabad
# 520      79.062770           NaN      Barauli Khurd
# 337      79.451555           NaN       Mohammadabad
# 537      78.145404         619.0            Aligarh
# 388      77.606110           NaN               None
# 555      77.358902         700.0          Ghaziabad
# 409      77.677524         732.0             Meerut
# 522      77.037438         829.0             Niawal
# 580      77.424560         891.0  Sherpur Naqeebpur
# 552      80.239197        4910.0        Pithoragarh
# 86       79.161665           NaN            Gauchar
# 533      78.323164        2983.0       Chinyalisour
# 526      79.213203       13700.0              Koyul
# 298      78.729710       13589.0              Nyoma
# 275      78.722140       14213.0            Chushul
# 525      76.155899        9604.0             Kargil
# 524      77.375801       10046.0              Nubra
#
#                             geometry
# 396  POINT (4303047.269 4016867.255)
# 398  POINT (4180496.385 4044854.623)
# 477  POINT (4092522.669 4127140.007)
# 67   POINT (4600536.118 4168078.584)
# 341  POINT (4350776.569 4179921.605)
# 342  POINT (4481106.979 4181190.652)
# 339  POINT (4147317.278 4182510.973)
# 460  POINT (4305916.623 4237331.075)
# 95   POINT (4766909.354 4041409.553)
# 98   POINT (4723717.698 4043783.248)
# 481  POINT (4666399.368 4064389.376)
# 501  POINT (4804056.258 4132916.525)
# 76   POINT (4692551.609 4152961.109)
# 466  POINT (4868426.729 4164161.301)
# 510   POINT (4728914.74 4210321.062)
# 577  POINT (4135338.277 4244954.831)
# 69   POINT (4200235.531 4245634.365)
# 66   POINT (4593545.131 4265828.444)
# 535  POINT (4251370.513 4268230.436)
# 544  POINT (4087046.141 4325025.009)
# 15   POINT (5017968.221 4217874.916)
# 89   POINT (4646954.578 4220677.591)
# 514  POINT (4971356.096 4266866.703)
# 476   POINT (4926840.961 4284357.51)
# 473    POINT (5465115.302 4454998.1)
# 356  POINT (5478774.495 4464564.005)
# 450  POINT (5507742.752 4469591.299)
# 483  POINT (5372949.005 4502658.792)
# 515  POINT (5557270.673 4517739.586)
# 506  POINT (5479151.793 4522525.055)
# 456  POINT (5356919.885 4568615.933)
# 303  POINT (5426407.091 4618153.284)
# 402  POINT (2886168.712 3959474.032)
# 565  POINT (4035732.193 4265252.587)
# 531  POINT (4022784.374 4273874.613)
# 338  POINT (3996868.108 4280535.552)
# 520  POINT (3908603.194 4317644.424)
# 337  POINT (3946684.227 4360539.562)
# 537   POINT (3820495.88 4420971.482)
# 388  POINT (3768884.072 4455971.292)
# 555  POINT (3746107.493 4514391.273)
# 409  POINT (3777088.674 4535359.402)
# 522  POINT (3717519.657 4624880.328)
# 580  POINT (3754985.835 4654705.807)
# 552  POINT (4022831.558 4608706.377)
# 86    POINT (3920429.97 4684440.297)
# 533   POINT (3841234.99 4717749.402)
# 526  POINT (3926946.938 4975461.904)
# 298  POINT (3882286.357 5001312.923)
# 275  POINT (3881970.664 5043852.986)
# 525  POINT (3647901.457 5155234.253)
# 524  POINT (3759886.386 5166870.399)

# %%
# simple
base=riversAll_buf.plot(color='yellow')
allRiversWithinBuffs.plot(ax=base, color='green', markersize=1)
# Out:
# <Axes: >

# %%
# folium

base=riversAll_buf.explore(color='yellow')
allRiversWithinBuffs.explore(m=base, color='green')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c968b2858eb64b420ec5e480ea3fed2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c968b2858eb64b420ec5e480ea3fed2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c968b2858eb64b420ec5e480ea3fed2 = L.map(
#                 &quot;map_5c968b2858eb64b420ec5e480ea3fed2&quot;,
#                 {
#                     center: [29.255284836519408, 81.982899689321],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_5c968b2858eb64b420ec5e480ea3fed2);
#
#
#
#
#
#             var tile_layer_b5e6d7b2c6c037751a09ada0fcf9e651 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b5e6d7b2c6c037751a09ada0fcf9e651.addTo(map_5c968b2858eb64b420ec5e480ea3fed2);
#
#
#             map_5c968b2858eb64b420ec5e480ea3fed2.fitBounds(
#                 [[22.635523043016295, 66.9933564448877], [35.87504663002252, 96.97244293375431]],
#                 {}
#             );
#
#
#         function geo_json_80ded79a6370b12497fd46f14c345b50_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;yellow&quot;, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_80ded79a6370b12497fd46f14c345b50_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_80ded79a6370b12497fd46f14c345b50_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_80ded79a6370b12497fd46f14c345b50_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_80ded79a6370b12497fd46f14c345b50_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_80ded79a6370b12497fd46f14c345b50.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_80ded79a6370b12497fd46f14c345b50_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_80ded79a6370b12497fd46f14c345b50 = L.geoJson(null, {
#                 onEachFeature: geo_json_80ded79a6370b12497fd46f14c345b50_onEachFeature,
#
#                 style: geo_json_80ded79a6370b12497fd46f14c345b50_styler,
#                 pointToLayer: geo_json_80ded79a6370b12497fd46f14c345b50_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_80ded79a6370b12497f
